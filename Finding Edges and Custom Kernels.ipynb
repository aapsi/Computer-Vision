# %% [markdown]
# # Creating a Filter, Edge Detection

# %% [markdown]
# ### Import resources and display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread('images/curved_lane.jpg')

plt.imshow(image)

# %% [markdown]
# ### Convert the image to grayscale

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

sobel_x = np.array([[-1,0,1],
                  [-2,0,2],
                  [-1,0,1]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.figure(figsize = (10,10))
plt.imshow(filtered_image,cmap = 'gray')
plt.title('sobel_y')
plt.show()

filtered_image_2 = cv2.filter2D(gray,-1,sobel_x)

plt.figure(figsize = (10,10))
plt.imshow(filtered_image_2,cmap = 'gray')
plt.title('sobel_x')
plt.show()

#creating a kernel to blur the images
blur = np.array([[0.05,0.1,0.05],
                [0.2,0.1,0.25],
                [0.15,0.1,0.05]])
blur = 1/10*(blur)

blur_image = cv2.filter2D(gray,-1,blur)
plt.figure(figsize = (10,10))
plt.imshow(blur_image,cmap = 'gray')
plt.title('blur')
plt.show()

find_edge = cv2.filter2D(gray,-1,sobel_x)
plt.figure(figsize = (10,10))
plt.imshow(find_edge,cmap = 'gray')
plt.title('series')
plt.show()

# %%
#using 5x5 filters
# Read in the image
image_2 = mpimg.imread('images/white_lines.jpg')

# Convert to grayscale for filtering
gray_2 = cv2.cvtColor(image_2, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_2, cmap='gray')
plt.show()

edge_detection_2 =  np.array([[-2,0,-2.5,0,-2],
                    [-2,0,-1,0,-2],
                    [-2.5,-1,12,-1,-2.5],
                    [-1,0,-1,0,-1],
                    [-1,0,-2.5,0,-1]])

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image_edges_2 = cv2.filter2D(gray_2, -1, edge_detection_2)

plt.figure(figsize = (15,15))
plt.imshow(filtered_image_edges_2, cmap='gray')
plt.show()
